# %%
! pip install sec-edgar-downloader
# Out:
# Collecting sec-edgar-downloader
#   Downloading sec_edgar_downloader-5.0.2-py3-none-any.whl (14 kB)
# Collecting requests
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting pyrate-limiter>=3.1.0
#   Downloading pyrate_limiter-3.6.0-py3-none-any.whl (26 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.7-py3-none-any.whl (66 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.3.2-cp310-cp310-macosx_11_0_arm64.whl (120 kB)
# Installing collected packages: urllib3, pyrate-limiter, idna, charset-normalizer, certifi, requests, sec-edgar-downloader
# Successfully installed certifi-2024.2.2 charset-normalizer-3.3.2 idna-3.7 pyrate-limiter-3.6.0 requests-2.31.0 sec-edgar-downloader-5.0.2 urllib3-2.2.1
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/Users/kaushalpatil/Development/GaTech Financial Services Lab/venv/bin/python3.10 -m pip install --upgrade pip' command.

# %%
from sec_edgar_downloader import Downloader
dl = Downloader("Kaushal Patil", "kaushalcode16@gmail.com")

# %%
# Get all 10-K filings for FAANG
dl.get("10-K", "AAPL")
dl.get("10-K", "AMZN")
dl.get("10-K", "META")
dl.get("10-K", "NFLX")
dl.get("10-K", "GOOG")
# Out:
# 9

# %%
! pip install sec-parser
# Out:
# Collecting sec-parser
#   Downloading sec_parser-0.56.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.8/75.8 KB 1.3 MB/s eta 0:00:00ta 0:00:01
# Requirement already satisfied: pandas<3.0.0,>=2.2.1 in ./venv/lib/python3.10/site-packages (from sec-parser) (2.2.2)
# Collecting tabulate<0.10.0,>=0.9.0
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting cssutils<3.0.0,>=2.10.2
#   Downloading cssutils-2.10.2-py3-none-any.whl (398 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 398.1/398.1 KB 5.8 MB/s eta 0:00:0000:01
# Collecting lxml<6.0.0,>=5.2.1
#   Downloading lxml-5.2.1-cp310-cp310-macosx_10_9_universal2.whl (8.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 7.3 MB/s eta 0:00:0000:0100:01
# Collecting xxhash<4.0.0,>=3.4.1
#   Downloading xxhash-3.4.1-cp310-cp310-macosx_11_0_arm64.whl (30 kB)
# Collecting loguru<0.8.0,>=0.7.2
#   Using cached loguru-0.7.2-py3-none-any.whl (62 kB)
# Collecting frozendict<3.0.0,>=2.4.1
#   Downloading frozendict-2.4.3-cp310-cp310-macosx_11_0_arm64.whl (37 kB)
# Collecting beautifulsoup4<5.0.0,>=4.12.3
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 KB 6.0 MB/s eta 0:00:00
# Collecting sec-downloader<0.12.0,>=0.11.1
#   Downloading sec_downloader-0.11.1-py3-none-any.whl (11 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.10/site-packages (from pandas<3.0.0,>=2.2.1->sec-parser) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.22.4 in ./venv/lib/python3.10/site-packages (from pandas<3.0.0,>=2.2.1->sec-parser) (1.26.4)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.10/site-packages (from pandas<3.0.0,>=2.2.1->sec-parser) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.10/site-packages (from pandas<3.0.0,>=2.2.1->sec-parser) (2024.1)
# Requirement already satisfied: sec-edgar-downloader in ./venv/lib/python3.10/site-packages (from sec-downloader<0.12.0,>=0.11.1->sec-parser) (5.0.2)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.2.1->sec-parser) (1.16.0)
# Requirement already satisfied: pyrate-limiter>=3.1.0 in ./venv/lib/python3.10/site-packages (from sec-edgar-downloader->sec-downloader<0.12.0,>=0.11.1->sec-parser) (3.6.0)
# Requirement already satisfied: requests in ./venv/lib/python3.10/site-packages (from sec-edgar-downloader->sec-downloader<0.12.0,>=0.11.1->sec-parser) (2.31.0)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.10/site-packages (from requests->sec-edgar-downloader->sec-downloader<0.12.0,>=0.11.1->sec-parser) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.10/site-packages (from requests->sec-edgar-downloader->sec-downloader<0.12.0,>=0.11.1->sec-parser) (2024.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.10/site-packages (from requests->sec-edgar-downloader->sec-downloader<0.12.0,>=0.11.1->sec-parser) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.10/site-packages (from requests->sec-edgar-downloader->sec-downloader<0.12.0,>=0.11.1->sec-parser) (2.2.1)
# Installing collected packages: xxhash, tabulate, soupsieve, lxml, loguru, frozendict, cssutils, beautifulsoup4, sec-downloader, sec-parser
# Successfully installed beautifulsoup4-4.12.3 cssutils-2.10.2 frozendict-2.4.3 loguru-0.7.2 lxml-5.2.1 sec-downloader-0.11.1 sec-parser-0.56.0 soupsieve-2.5 tabulate-0.9.0 xxhash-3.4.1
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/Users/kaushalpatil/Development/GaTech Financial Services Lab/venv/bin/python3.10 -m pip install --upgrade pip' command.

# %%
import warnings
from sec_downloader import Downloader
import sec_parser as sp

dl = Downloader("Kaushal Patil", "kaushalcode16@gmail.com")
html = dl.get_filing_html(ticker="AAPL", form="10-K")
parser = sp.Edgar10QParser()

with warnings.catch_warnings():
    warnings.filterwarnings("ignore", message="Invalid section type for")
    elements: list = parser.parse(html)
    
tree: sp.SemanticTree = sp.TreeBuilder().build(elements)

demo_output: str = sp.render(tree)
print('\n'.join(demo_output.split('\n')))
# Out:
# TopSectionTitle: PART I
# ├── TopSectionTitle: Item 1.    Business
# │   ├── TitleElement: Company Background
# │   │   └── TextElement: The Company designs, manufactur...the last Saturday of September.
# │   ├── TitleElement: Products
# │   │   ├── TitleElement: iPhone
# │   │   │   └── TextElement: iPhone® is the Company’s line o...e 14, iPhone 13 and iPhone SE®.
# │   │   ├── TitleElement: Mac
# │   │   │   └── TextElement: Mac® is the Company’s line of p...ini®, Mac Studio® and Mac Pro®.
# │   │   ├── TitleElement: iPad
# │   │   │   └── TextElement: iPad® is the Company’s line of ...iPad Air®, iPad and iPad mini®.
# │   │   └── TitleElement: Wearables, Home and Accessories
# │   │       └── TextElement: Wearables includes smartwatches...ed and third-party accessories.
# │   ├── TitleElement: Services
# │   │   ├── TitleElement: Advertising
# │   │   │   └── TextElement: The Company’s advertising servi...ny’s own advertising platforms.
# │   │   ├── TitleElement: AppleCare
# │   │   │   └── TextElement: The Company offers a portfolio ...he country and type of product.
# │   │   ├── TitleElement: Cloud Services
# │   │   │   └── TextElement: The Company’s cloud services st...and Windows personal computers.
# │   │   ├── TitleElement: Digital Content
# │   │   │   └── TextElement: The Company operates various pl...iginal content and live sports.
# │   │   └── TitleElement: Payment Services
# │   │       └── TextElement: The Company offers payment serv...y®, a cashless payment service.
# │   ├── TitleElement: Segments
# │   │   └── TextElement: The Company manages its busines...mics of each geographic region.
# │   ├── TitleElement: Markets and Distribution
# │   │   └── TextElement: The Company’s customers are pri...spectively, of total net sales.
# │   ├── TitleElement: Competition
# │   │   └── TextElement: The markets for the Company’s p...han those they currently offer.
# │   ├── TitleElement: Supply of Components
# │   │   └── TextElement: Although most components essent...ts on similar terms, or at all.
# │   ├── TitleElement: Research and Development
# │   │   └── TextElement: Because the industries in which...arty businesses and technology.
# │   ├── TitleElement: Intellectual Property
# │   │   └── TextElement: The Company currently holds a b... on reasonable terms or at all.
# │   ├── TitleElement: Business Seasonality and Product Introductions
# │   │   └── TextElement: The Company has historically ex...icipate a product introduction.
# │   ├── TitleElement: Human Capital
# │   │   ├── TextElement: The Company believes it has a t...full-time equivalent employees.
# │   │   ├── TitleElement: Workplace Practices and Policies
# │   │   │   └── TextElement: The Company is an equal opportu...f harassment or discrimination.
# │   │   ├── TitleElement: Compensation and Benefits
# │   │   │   └── TextElement: The Company believes that compe...ividual growth and development.
# │   │   ├── TitleElement: Inclusion and Diversity
# │   │   │   └── TextElement: The Company is committed to its... opportunity for all employees.
# │   │   ├── TitleElement: Engagement
# │   │   │   └── TextElement: The Company believes that open ...er performance and inclusivity.
# │   │   └── TitleElement: Health and Safety
# │   │       └── TextElement: The Company is committed to pro...rough its global security team.
# │   ├── TitleElement: Available Information
# │   │   └── TextElement: The Company’s Annual Reports on...active textual references only.
# │   ├── TitleElement: Item 1A.    Risk Factors
# │   │   ├── TextElement: The Company’s business, reputat...ins forward-looking statements.
# │   │   └── SupplementaryText: This section should be read in ...entary Data” of this Form 10-K.
# │   ├── TitleElement: Macroeconomic and Industry Risks
# │   │   ├── SupplementaryText: The Company’s operations and pe...ations and financial condition.
# │   │   ├── TextElement: The Company has international o...cial condition and stock price.
# │   │   ├── SupplementaryText: The Company’s business can be i...d other business interruptions.
# │   │   ├── TextElement: Political events, trade and oth...over all losses that may arise.
# │   │   ├── SupplementaryText: Global markets for the Company’...e effectively in these markets.
# │   │   └── TextElement: The Company’s products and serv...vices that compete effectively.
# │   ├── TitleElement: Business Risks
# │   │   ├── SupplementaryText: To remain competitive and stimu...tions of products and services.
# │   │   ├── TextElement: Due to the highly volatile and ...tions of products and services.
# │   │   ├── SupplementaryText: The Company depends on componen...are located outside of the U.S.
# │   │   ├── TextElement: Substantially all of the Compan...nts can be negatively impacted.
# │   │   ├── SupplementaryText: Future operating results depend... commercially reasonable terms.
# │   │   ├── TextElement: Because the Company currently o...ies from an alternative source.
# │   │   ├── SupplementaryText: The Company’s products and serv...rm to the Company’s reputation.
# │   │   ├── TextElement: The Company offers complex hard...e introductions and lost sales.
# │   │   ├── SupplementaryText: The Company is exposed to the r...e commitment cancellation risk.
# │   │   ├── TextElement: The Company records a write-dow...lize firm purchase commitments.
# │   │   ├── SupplementaryText: The Company relies on access to...lly reasonable terms or at all.
# │   │   ├── TextElement: The Company’s products and serv...ations and financial condition.
# │   │   ├── SupplementaryText: The Company’s future performanc...hird-party software developers.
# │   │   ├── TextElement: The Company believes decisions ... materially adversely affected.
# │   │   ├── SupplementaryText: Failure to obtain or create dig...ations and financial condition.
# │   │   ├── TextElement: The Company contracts with nume...le cost and in a timely manner.
# │   │   ├── SupplementaryText: The Company’s success depends l...tinctive and inclusive culture.
# │   │   ├── TextElement: Much of the Company’s future su...ations and financial condition.
# │   │   ├── SupplementaryText: The Company depends on the perf... retailers and other resellers.
# │   │   ├── TextElement: The Company distributes its pro...ting of the Company’s products.
# │   │   ├── SupplementaryText: The Company’s business and repu...ilures and network disruptions.
# │   │   ├── TextElement: The Company and its global supp...ations and financial condition.
# │   │   ├── SupplementaryText: Losses or unauthorized access t...l and operational consequences.
# │   │   ├── TextElement: The Company’s business requires...types of claims that may arise.
# │   │   ├── SupplementaryText: Investment in new business stra...ations and financial condition.
# │   │   ├── TextElement: The Company has invested, and i...ations and financial condition.
# │   │   ├── SupplementaryText: The Company’s retail stores are...merous risks and uncertainties.
# │   │   └── TextElement: The Company’s retail operations...locations at a reasonable cost.
# │   ├── TitleElement: Legal and Regulatory Compliance Risks
# │   │   ├── SupplementaryText: The Company’s business, results...s or government investigations.
# │   │   ├── TextElement: The Company is subject to vario... certain products and services.
# │   │   ├── SupplementaryText: Except as described in Part I, ...sserted legal and other claims.
# │   │   ├── TextElement: The outcome of litigation or go...types of claims that may arise.
# │   │   ├── SupplementaryText: The Company is subject to compl...ects on the Company’s business.
# │   │   ├── TextElement: The Company’s global operations...ations and financial condition.
# │   │   ├── SupplementaryText: Expectations relating to enviro...ects on the Company’s business.
# │   │   ├── TextElement: Many governments, regulators, i...cial condition and stock price.
# │   │   ├── SupplementaryText: The technology industry, includ...s, legal actions and penalties.
# │   │   ├── TextElement: From time to time, the Company ...s and services, and lost sales.
# │   │   ├── SupplementaryText: The Company’s business is subje...ions regarding data protection.
# │   │   └── TextElement: The Company is subject to an in...ations and financial condition.
# │   ├── TitleElement: Financial Risks
# │   │   ├── SupplementaryText: The Company expects its quarter...lts of operations to fluctuate.
# │   │   ├── TextElement: The Company’s profit margins va...ply, or manufacturing partners.
# │   │   ├── SupplementaryText: The Company’s financial perform...r relative to local currencies.
# │   │   ├── TextElement: The Company’s primary exposure ...d time the hedges are in place.
# │   │   ├── SupplementaryText: The Company is exposed to credi...es of its investment portfolio.
# │   │   ├── TextElement: The Company’s investments can b...ations and financial condition.
# │   │   ├── SupplementaryText: The Company is exposed to credi...hen economic conditions worsen.
# │   │   ├── TextElement: The Company distributes its pro...s credit risk and avoid losses.
# │   │   ├── SupplementaryText: The Company is subject to chang... to additional tax liabilities.
# │   │   └── TextElement: The Company is subject to taxes... materially adversely affected.
# │   ├── TitleElement: General Risks
# │   │   ├── SupplementaryText: The price of the Company’s stock is subject to volatility.
# │   │   └── TextElement: The Company’s stock has experie...fidence and employee retention.
# │   ├── TitleElement: Item 1B.    Unresolved Staff Comments
# │   │   └── TextElement: None.
# │   └── TitleElement: Item 1C.    Cybersecurity
# │       └── TextElement: Not applicable.
# ├── TopSectionTitle: Item 2.    Properties
# │   └── TextElement: The Company’s headquarters is l...or the conduct of its business.
# ├── TopSectionTitle: Item 3.    Legal Proceedings
# │   ├── TitleElement: Epic Games
# │   │   └── TextElement: Epic Games, Inc. (“Epic”) filed... of the injunction will expire.
# │   ├── TitleElement: Masimo
# │   │   └── TextElement: Masimo Corporation and Cercacor...seek a stay pending the appeal.
# │   └── TitleElement: Other Legal Proceedings
# │       └── TextElement: The Company is subject to other... materially adversely affected.
# └── TopSectionTitle: Item 4.    Mine Safety Disclosures
#     └── TextElement: Not applicable.
# TopSectionTitle: PART II
# ├── TopSectionTitle: Item 5.    Market for Registran... Purchases of Equity Securities
# │   ├── TextElement: The Company’s common stock is t...rket LLC under the symbol AAPL.
# │   ├── TitleElement: Holders
# │   │   └── TextElement: As of October 20, 2023, there were 23,763 shareholders of record.
# │   ├── TitleElement: Purchases of Equity Securities ...ssuer and Affiliated Purchasers
# │   │   ├── TextElement: Share repurchase activity durin...usands, and per-share amounts):
# │   │   ├── TableElement: Table with ~9 rows, ~21 numbers, and 603 characters.
# │   │   └── TextElement: (1)As of September 30, 2023, th...d in the first quarter of 2024.
# │   └── TitleElement: Company Stock Performance
# │       ├── TextElement: The following graph shows a com...future stock price performance.
# │       ├── ImageElement
# │       └── TableElement: Table with ~3 rows, ~25 numbers, and 238 characters.
# └── TopSectionTitle: Item 6.    [Reserved]
#     ├── TitleElement: Item 7.    Management’s Discuss...ition and Results of Operations
#     │   └── SupplementaryText: The following discussion should... year ended September 24, 2022.
#     ├── TitleElement: Fiscal Period
#     │   └── TextElement: The Company’s fiscal year is th...and 2021 spanned 52 weeks each.
#     ├── TitleElement: Fiscal Year Highlights
#     │   ├── TextElement: The Company’s total net sales w...d equivalents of $15.0 billion.
#     │   └── TitleElement: Macroeconomic Conditions
#     │       └── TextElement: Macroeconomic conditions, inclu...ations and financial condition.
#     ├── TitleElement: Segment Operating Performance
#     │   ├── TextElement: The following table shows net s...and 2021 (dollars in millions):
#     │   ├── TableElement: Table with ~7 rows, ~33 numbers, and 304 characters.
#     │   ├── TitleElement: Americas
#     │   │   └── TextElement: Americas net sales decreased 4%...y higher net sales of Services.
#     │   ├── TitleElement: Europe
#     │   │   └── TextElement: Europe net sales decreased 1% o...t sales of iPhone and Services.
#     │   ├── TitleElement: Greater China
#     │   │   └── TextElement: Greater China net sales decreas...er net sales of Mac and iPhone.
#     │   ├── TitleElement: Japan
#     │   │   └── TextElement: Japan net sales decreased 7% or..., Home and Accessories and Mac.
#     │   └── TitleElement: Rest of Asia Pacific
#     │       └── TextElement: Rest of Asia Pacific net sales ...ower net sales of Mac and iPad.
#     ├── TitleElement: Products and Services Performance
#     │   ├── TextElement: The following table shows net s...and 2021 (dollars in millions):
#     │   ├── TableElement: Table with ~7 rows, ~38 numbers, and 315 characters.
#     │   ├── TextElement: (1)Products net sales include a...ales price of certain products.
#     │   ├── TitleElement: iPhone
#     │   │   └── TextElement: iPhone net sales decreased 2% o...net sales of Pro iPhone models.
#     │   ├── TitleElement: Mac
#     │   │   └── TextElement: Mac net sales decreased 27% or ... to lower net sales of laptops.
#     │   ├── TitleElement: iPad
#     │   │   └── TextElement: iPad net sales decreased 3% or ...f iPad 9th and 10th generation.
#     │   ├── TitleElement: Wearables, Home and Accessories
#     │   │   └── TextElement: Wearables, Home and Accessories...s of Wearables and Accessories.
#     │   └── TitleElement: Services
#     │       └── TextElement: Services net sales increased 9%...s across all lines of business.
#     ├── TitleElement: Gross Margin
#     │   ├── TextElement: Products and Services gross mar... follows (dollars in millions):
#     │   ├── TableElement: Table with ~4 rows, ~12 numbers, and 133 characters.
#     │   ├── TableElement: Table with ~4 rows, ~9 numbers, and 123 characters.
#     │   ├── TitleElement: Products Gross Margin
#     │   │   └── TextElement: Products gross margin decreased... dollar and decreased leverage.
#     │   └── TitleElement: Services Gross Margin
#     │       └── TextElement: Services gross margin increased...latility and downward pressure.
#     ├── TitleElement: Operating Expenses
#     │   ├── TextElement: Operating expenses for 2023, 20... follows (dollars in millions):
#     │   ├── TableElement: Table with ~6 rows, ~27 numbers, and 319 characters.
#     │   ├── TitleElement: Research and Development
#     │   │   └── TextElement: The year-over-year growth in R&... in headcount-related expenses.
#     │   └── TitleElement: Selling, General and Administrative
#     │       └── TextElement: Selling, general and administra... flat in 2023 compared to 2022.
#     ├── TitleElement: Provision for Income Taxes
#     │   ├── TextElement: Provision for income taxes, eff... follows (dollars in millions):
#     │   ├── TableElement: Table with ~3 rows, ~12 numbers, and 143 characters.
#     │   └── TextElement: The Company’s effective tax rat... from share-based compensation.
#     ├── TitleElement: Liquidity and Capital Resources
#     │   ├── TextElement: The Company believes its balanc...lowing contractual obligations:
#     │   ├── TitleElement: Debt
#     │   │   └── TextElement: As of September 30, 2023, the C...h was payable within 12 months.
#     │   ├── TitleElement: Leases
#     │   │   └── TextElement: The Company has lease arrangeme...llion payable within 12 months.
#     │   ├── TitleElement: Manufacturing Purchase Obligations
#     │   │   └── TextElement: The Company utilizes several ou...ns are primarily noncancelable.
#     │   ├── TitleElement: Other Purchase Obligations
#     │   │   └── TextElement: The Company’s other purchase ob...llion payable within 12 months.
#     │   ├── TitleElement: Deemed Repatriation Tax Payable
#     │   │   └── TextElement: As of September 30, 2023, the b...ed to be paid within 12 months.
#     │   └── TitleElement: Capital Return Program
#     │       └── TextElement: In addition to its contractual ...tion by the Board of Directors.
#     ├── TitleElement: Critical Accounting Estimates
#     │   ├── TextElement: The preparation of financial st...lues of assets and liabilities.
#     │   ├── TitleElement: Uncertain Tax Positions
#     │   │   └── TextElement: The Company is subject to incom...ondition and operating results.
#     │   └── TitleElement: Legal and Other Contingencies
#     │       └── TextElement: The Company is subject to vario...ondition and operating results.
#     ├── TitleElement: Item 7A.    Quantitative and Qu...e Disclosures About Market Risk
#     │   └── TextElement: The Company is exposed to econo...solidated financial statements.
#     ├── TitleElement: Interest Rate Risk
#     │   ├── TextElement: The Company is primarily expose...24, 2022 (dollars in millions):
#     │   └── TableElement: Table with ~3 rows, ~8 numbers, and 255 characters.
#     ├── TitleElement: Foreign Exchange Rate Risk
#     │   └── TextElement: The Company’s exposure to forei...s foreign currency derivatives.
#     ├── TitleElement: Item 8.    Financial Statements and Supplementary Data
#     │   ├── TableOfContentsElement: Table with ~8 rows, ~12 numbers, and 729 characters.
#     │   ├── SupplementaryText: All financial statement schedul...tements and accompanying notes.
#     │   ├── TitleElement: CONSOLIDATED STATEMENTS OF OPERATIONS
#     │   │   ├── SupplementaryText: (In millions, except number of ...ousands, and per-share amounts)
#     │   │   ├── TableElement: Table with ~24 rows, ~60 numbers, and 920 characters.
#     │   │   └── SupplementaryText: See accompanying Notes to Consolidated Financial Statements.
#     │   ├── TitleElement: CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME
#     │   │   ├── SupplementaryText: (In millions)
#     │   │   ├── TableElement: Table with ~13 rows, ~33 numbers, and 920 characters.
#     │   │   └── SupplementaryText: See accompanying Notes to Consolidated Financial Statements.
#     │   ├── TitleElement: CONSOLIDATED BALANCE SHEETS
#     │   │   ├── SupplementaryText: (In millions, except number of ...ed in thousands, and par value)
#     │   │   ├── TableElement: Table with ~35 rows, ~57 numbers, and 1342 characters.
#     │   │   └── SupplementaryText: See accompanying Notes to Consolidated Financial Statements.
#     │   ├── TitleElement: CONSOLIDATED STATEMENTS OF SHAREHOLDERS’ EQUITY
#     │   │   ├── SupplementaryText: (In millions, except per-share amounts)
#     │   │   ├── TableElement: Table with ~20 rows, ~54 numbers, and 1080 characters.
#     │   │   └── SupplementaryText: See accompanying Notes to Consolidated Financial Statements.
#     │   └── TitleElement: CONSOLIDATED STATEMENTS OF CASH FLOWS
#     │       ├── SupplementaryText: (In millions)
#     │       ├── TableElement: Table with ~36 rows, ~93 numbers, and 1959 characters.
#     │       ├── SupplementaryText: See accompanying Notes to Consolidated Financial Statements.
#     │       └── TitleElement: Notes to Consolidated Financial Statements
#     ├── TitleElement: Note 1 – Summary of Significant Accounting Policies
#     ├── TitleElement: Basis of Presentation and Preparation
#     │   ├── TextElement: The consolidated financial stat... current period’s presentation.
#     │   └── TextElement: The Company’s fiscal year is th... periods of those fiscal years.
#     ├── TitleElement: Revenue
#     │   └── TextElement: The Company records revenue net...ed to governmental authorities.
#     ├── TitleElement: Share-Based Compensation
#     │   └── TextElement: The Company recognizes share-ba...ards that will ultimately vest.
#     ├── TitleElement: Cash Equivalents
#     │   └── TextElement: All highly liquid investments w...re treated as cash equivalents.
#     ├── TitleElement: Marketable Securities
#     │   └── TextElement: The cost of securities sold is ...specific identification method.
#     ├── TitleElement: Inventories
#     │   └── TextElement: Inventories are measured using the first-in, first-out method.
#     ├── TitleElement: Property, Plant and Equipment
#     │   └── TextElement: Depreciation on property, plant...nized on a straight-line basis.
#     ├── TitleElement: Derivative Instruments
#     │   └── TextElement: The Company presents derivative...he Consolidated Balance Sheets.
#     ├── TitleElement: Income Taxes
#     │   └── TextElement: The Company records certain def...gn earnings created by the Act.
#     ├── TitleElement: Leases
#     │   └── TextElement: The Company combines and accoun...a center and retail facilities.
#     ├── TitleElement: Note 2 – Revenue
#     │   ├── TextElement: The Company recognizes revenue ...only the commission it retains.
#     │   ├── TextElement: Net sales disaggregated by sign... were as follows (in millions):
#     │   ├── TableElement: Table with ~6 rows, ~26 numbers, and 236 characters.
#     │   ├── TextElement: (1)Products net sales include a...ales price of certain products.
#     │   └── TextElement: Total net sales include $8.2 bi...1% in greater than three years.
#     ├── TitleElement: Note 3 – Earnings Per Share
#     │   ├── TextElement: The following table shows the c...lions and shares in thousands):
#     │   ├── TableElement: Table with ~8 rows, ~21 numbers, and 351 characters.
#     │   └── TextElement: Approximately 24 million restri...t would have been antidilutive.
#     ├── TitleElement: Note 4 – Financial Instruments
#     ├── TitleElement: Cash, Cash Equivalents and Marketable Securities
#     │   ├── TextElement: The following tables show the C...ptember 24, 2022 (in millions):
#     │   ├── TableElement: Table with ~16 rows, ~78 numbers, and 917 characters.
#     │   ├── TableElement: Table with ~16 rows, ~74 numbers, and 902 characters.
#     │   ├── TextElement: (1)The valuation techniques use...e Taxes”) and other agreements.
#     │   ├── TextElement: The following table shows the f...ptember 30, 2023 (in millions):
#     │   ├── TableElement: Table with ~4 rows, ~7 numbers, and 129 characters.
#     │   └── TextElement: The Company’s investments in ma...ying contractual maturity date.
#     ├── TitleElement: Derivative Instruments and Hedging
#     │   ├── TextElement: The Company may use derivative ...sified as operating activities.
#     │   ├── TitleElement: Foreign Exchange Rate Risk
#     │   │   └── TextElement: To protect gross margins from f...d in non-functional currencies.
#     │   └── TitleElement: Interest Rate Risk
#     │       ├── TextElement: To protect the Company’s term d...cash flow or fair value hedges.
#     │       ├── TextElement: The notional amounts of the Com... were as follows (in millions):
#     │       ├── TableElement: Table with ~5 rows, ~8 numbers, and 247 characters.
#     │       ├── TextElement: The gross fair values of the Co... were as follows (in millions):
#     │       ├── TableElement: Table with ~5 rows, ~11 numbers, and 315 characters.
#     │       ├── TextElement: (1)Derivative assets are measur...the Consolidated Balance Sheet.
#     │       ├── TextElement: The derivative assets above rep...rivative asset of $412 million.
#     │       ├── TextElement: The carrying amounts of the Com... were as follows (in millions):
#     │       └── TableElement: Table with ~3 rows, ~6 numbers, and 148 characters.
#     ├── TitleElement: Accounts Receivable
#     │   ├── TitleElement: Trade Receivables
#     │   │   └── TextElement: As of September 24, 2022, the C...customers to limit credit risk.
#     │   └── TitleElement: Vendor Non-Trade Receivables
#     │       └── TextElement: The Company has non-trade recei...hich accounted for 54% and 13%.
#     ├── TitleElement: Note 5 – Property, Plant and Equipment
#     │   ├── TextElement: The following table shows the C...ptember 24, 2022 (in millions):
#     │   ├── TableElement: Table with ~6 rows, ~14 numbers, and 284 characters.
#     │   └── TextElement: Depreciation expense on propert...3, 2022 and 2021, respectively.
#     ├── TitleElement: Note 6 – Consolidated Financial Statement Details
#     │   └── TextElement: The following tables show the C...ptember 24, 2022 (in millions):
#     ├── TitleElement: Other Non-Current Assets
#     │   └── TableElement: Table with ~3 rows, ~8 numbers, and 126 characters.
#     ├── TitleElement: Other Current Liabilities
#     │   └── TableElement: Table with ~3 rows, ~8 numbers, and 127 characters.
#     ├── TitleElement: Other Non-Current Liabilities
#     │   └── TableElement: Table with ~3 rows, ~8 numbers, and 140 characters.
#     ├── TitleElement: Other Income/(Expense), Net
#     │   ├── TextElement: The following table shows the d...3, 2022 and 2021 (in millions):
#     │   └── TableElement: Table with ~4 rows, ~15 numbers, and 187 characters.
#     ├── TitleElement: Note 7 – Income Taxes
#     ├── TitleElement: Provision for Income Taxes and Effective Tax Rate
#     │   ├── TextElement: The provision for income taxes ...of the following (in millions):
#     │   ├── TableElement: Table with ~13 rows, ~33 numbers, and 305 characters.
#     │   ├── TextElement: The foreign provision for incom...3, 2022 and 2021, respectively.
#     │   ├── TextElement: A reconciliation of the provisi... follows (dollars in millions):
#     │   └── TableElement: Table with ~9 rows, ~29 numbers, and 440 characters.
#     ├── TitleElement: Deferred Tax Assets and Liabilities
#     │   ├── TextElement: As of September 30, 2023 and Se...liabilities were (in millions):
#     │   ├── TableElement: Table with ~19 rows, ~36 numbers, and 629 characters.
#     │   └── TextElement: As of September 30, 2023, the C...of other temporary differences.
#     ├── TitleElement: Uncertain Tax Positions
#     │   ├── TextElement: As of September 30, 2023, the t...e Company’s effective tax rate.
#     │   ├── TextElement: The aggregate change in the bal...1, is as follows (in millions):
#     │   ├── TableElement: Table with ~7 rows, ~24 numbers, and 478 characters.
#     │   └── TextElement: The Company is subject to taxat...ths by as much as $4.5 billion.
#     ├── TitleElement: European Commission State Aid Decision
#     │   └── TextElement: On August 30, 2016, the Europea...truments” for more information.
#     ├── TitleElement: Note 8 – Leases
#     │   ├── TextElement: The Company has lease arrangeme...3, 2022 and 2021, respectively.
#     │   ├── TextElement: The following table shows ROU a...ptember 24, 2022 (in millions):
#     │   ├── TableElement: Table with ~9 rows, ~18 numbers, and 486 characters.
#     │   ├── TextElement: Lease liability maturities as o..., are as follows (in millions):
#     │   ├── TableElement: Table with ~9 rows, ~32 numbers, and 296 characters.
#     │   └── TextElement: The weighted-average remaining ...anging from 1 year to 21 years.
#     ├── TitleElement: Note 9 – Debt
#     ├── TitleElement: Commercial Paper
#     │   ├── TextElement: The Company issues unsecured sh...3, 2022 and 2021 (in millions):
#     │   └── TableElement: Table with ~7 rows, ~19 numbers, and 387 characters.
#     ├── TitleElement: Term Debt
#     │   ├── TextElement: The Company has outstanding Not...0, 2023 and September 24, 2022:
#     │   ├── TableElement: Table with ~10 rows, ~26 numbers, and 617 characters.
#     │   ├── TextElement: To manage interest rate risk on...3, 2022 and 2021, respectively.
#     │   ├── TextElement: The future principal payments f..., are as follows (in millions):
#     │   ├── TableElement: Table with ~7 rows, ~12 numbers, and 103 characters.
#     │   └── TextElement: As of September 30, 2023 and Se...nd $98.8 billion, respectively.
#     ├── TitleElement: Note 10 – Shareholders’ Equity
#     ├── TitleElement: Share Repurchase Program
#     │   └── TextElement: During 2023, the Company repurc... 10b5-1 under the Exchange Act.
#     ├── TitleElement: Shares of Common Stock
#     │   ├── TextElement: The following table shows the c..., 2022 and 2021 (in thousands):
#     │   └── TableElement: Table with ~4 rows, ~15 numbers, and 297 characters.
#     ├── TitleElement: Note 11 – Share-Based Compensation
#     ├── TitleElement: 2022 Employee Stock Plan
#     │   └── TextElement: The Apple Inc. 2022 Employee St... was approved on March 4, 2022.
#     ├── TitleElement: 2014 Employee Stock Plan
#     │   └── TextElement: The Apple Inc. 2014 Employee St...new awards under the 2014 Plan.
#     ├── TitleElement: Restricted Stock Units
#     │   ├── TextElement: A summary of the Company’s RSU ..., 2022 and 2021, is as follows:
#     │   ├── TableElement: Table with ~13 rows, ~31 numbers, and 546 characters.
#     │   └── TextElement: The fair value as of the respec...3, 2022 and 2021, respectively.
#     ├── TitleElement: Share-Based Compensation
#     │   ├── TextElement: The following table shows share...3, 2022 and 2021 (in millions):
#     │   ├── TableElement: Table with ~2 rows, ~9 numbers, and 152 characters.
#     │   └── TextElement: As of September 30, 2023, the t...ed-average period of 2.5 years.
#     ├── TitleElement: Note 12 – Commitments, Contingencies and Supply Concentrations
#     ├── TitleElement: Unconditional Purchase Obligations
#     │   ├── TextElement: The Company has entered into ce..., are as follows (in millions):
#     │   └── TableElement: Table with ~7 rows, ~12 numbers, and 79 characters.
#     ├── TitleElement: Contingencies
#     │   └── TextElement: The Company is subject to vario...sserted legal and other claims.
#     ├── TitleElement: Concentrations in the Available...Supply of Materials and Product
#     │   └── TextElement: Although most components essent...outh Korea, Taiwan and Vietnam.
#     ├── TitleElement: Note 13 – Segment Information and Geographic Data
#     │   ├── TextElement: The Company manages its busines...nce excludes asset information.
#     │   ├── TextElement: The following table shows infor...3, 2022 and 2021 (in millions):
#     │   ├── TableElement: Table with ~15 rows, ~33 numbers, and 435 characters.
#     │   ├── TextElement: A reconciliation of the Company...21 is as follows (in millions):
#     │   ├── TableElement: Table with ~4 rows, ~16 numbers, and 221 characters.
#     │   ├── TextElement: (1)Includes corporate marketing...neral and administrative costs.
#     │   ├── TextElement: The U.S. and China were the onl... were as follows (in millions):
#     │   ├── TableElement: Table with ~5 rows, ~16 numbers, and 163 characters.
#     │   ├── TableElement: Table with ~5 rows, ~11 numbers, and 132 characters.
#     │   ├── TextElement: (1)China includes Hong Kong and Taiwan.
#     │   └── TitleElement: Report of Independent Registered Public Accounting Firm
#     │       └── TextElement: To the Shareholders and the Board of Directors of Apple Inc.
#     ├── TitleElement: Opinion on the Financial Statements
#     │   └── TextElement: We have audited the accompanyin...an unqualified opinion thereon.
#     ├── TitleElement: Basis for Opinion
#     │   └── TextElement: These financial statements are ...asonable basis for our opinion.
#     ├── TitleElement: Critical Audit Matter
#     │   ├── TextElement: The critical audit matter commu...ose, CaliforniaNovember 2, 2023
#     │   └── TitleElement: Report of Independent Registered Public Accounting Firm
#     │       └── TextElement: To the Shareholders and the Board of Directors of Apple Inc.
#     ├── TitleElement: Opinion on Internal Control Over Financial Reporting
#     │   └── TextElement: We have audited Apple Inc.’s in...an unqualified opinion thereon.
#     ├── TitleElement: Basis for Opinion
#     │   └── TextElement: Apple Inc.’s management is resp...asonable basis for our opinion.
#     ├── TitleElement: Definition and Limitations of I...ontrol Over Financial Reporting
#     │   └── TextElement: A company’s internal control ov...ose, CaliforniaNovember 2, 2023
#     ├── TitleElement: Item 9.    Changes in and Disag...unting and Financial Disclosure
#     │   └── TextElement: None.
#     ├── TitleElement: Item 9A.    Controls and Procedures
#     ├── TitleElement: Evaluation of Disclosure Controls and Procedures
#     │   └── TextElement: Based on an evaluation under th... regarding required disclosure.
#     ├── TitleElement: Inherent Limitations over Internal Controls
#     │   └── TextElement: The Company’s internal control ... or procedures may deteriorate.
#     ├── TitleElement: Management’s Annual Report on I...ontrol over Financial Reporting
#     │   └── TextElement: The Company’s management is res...t II, Item 8 of this Form 10-K.
#     ├── TitleElement: Changes in Internal Control over Financial Reporting
#     │   └── TextElement: There were no changes in the Co...ntrol over financial reporting.
#     ├── TitleElement: Item 9B.    Other Information
#     ├── TitleElement: Insider Trading Arrangements
#     │   └── TextElement: On August 30, 2023, Deirdre O’B... events set forth in the plans.
#     ├── TitleElement: Item 9C.    Disclosure Regardin...ctions that Prevent Inspections
#     │   ├── TextElement: Not applicable.
#     │   └── TitleElement: PART III
#     ├── TitleElement: Item 10.    Directors, Executiv...ficers and Corporate Governance
#     │   └── TextElement: The information required by thi...corporated herein by reference.
#     ├── TitleElement: Item 11.    Executive Compensation
#     │   └── TextElement: The information required by thi...corporated herein by reference.
#     ├── TitleElement: Item 12.    Security Ownership ...and Related Stockholder Matters
#     │   └── TextElement: The information required by thi...corporated herein by reference.
#     ├── TitleElement: Item 13.    Certain Relationshi...ions, and Director Independence
#     │   └── TextElement: The information required by thi...corporated herein by reference.
#     ├── TitleElement: Item 14.    Principal Accountant Fees and Services
#     │   ├── TextElement: The information required by thi...corporated herein by reference.
#     │   └── TitleElement: PART IV
#     ├── TitleElement: Item 15.    Exhibit and Financial Statement Schedules
#     ├── TitleElement: (a)Documents filed as part of this report
#     ├── TitleElement: (1)All financial statements
#     │   ├── TableOfContentsElement: Table with ~8 rows, ~12 numbers, and 730 characters.
#     │   └── TextElement: *Ernst & Young LLP, PCAOB Firm ID No. 00042.
#     ├── TitleElement: (2)Financial Statement Schedules
#     │   ├── SupplementaryText: All financial statement schedul...tes included in this Form 10-K.
#     │   ├── SupplementaryText: (3)Exhibits required by Item 601 of Regulation S-K (1)
#     │   ├── TableElement: Table with ~12 rows, ~51 numbers, and 2171 characters.
#     │   ├── TableElement: Table with ~20 rows, ~95 numbers, and 4402 characters.
#     │   ├── TableElement: Table with ~30 rows, ~119 numbers, and 3387 characters.
#     │   ├── TableElement: Table with ~2 rows, ~2 numbers, and 221 characters.
#     │   └── TextElement: *Indicates management contract ...copies of any such instruments.
#     └── TitleElement: Item 16.    Form 10-K Summary
#         ├── TextElement: None.
#         └── TitleElement: SIGNATURES
#             ├── TextElement: Pursuant to the requirements of...esident,Chief Financial Officer
#             └── TitleElement: Power of Attorney
#                 ├── TextElement: KNOW ALL PERSONS BY THESE PRESE...ies and on the dates indicated:
#                 └── TableElement: Table with ~23 rows, ~11 numbers, and 844 characters.
